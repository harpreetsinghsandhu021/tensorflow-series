# %% [markdown]
# # Basic Classification - Classify Images of Clothing

# %%
# %pip install tensorflow tensorflow-macos tensorflow-metal
# Out:
# ...
#   Using cached tensorflow-2.16.2-cp39-cp39-macosx_12_0_arm64.whl.metadata (4.1 kB)
# ...
#   Using cached ml_dtypes-0.3.2-cp39-cp39-macosx_10_9_universal2.whl.metadata (20 kB)
# ...
#   Using cached tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 MB 13.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 14.2 MB/s eta 0:00:001m14.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 13.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 14.1 MB/s eta 0:00:0031m14.4 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 14.1 MB/s eta 0:00:0031m15.0 MB/s eta 0:00:01
# ...

# %%
import tensorflow as tf
import numpy as np 
import matplotlib.pyplot as plt

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 3us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Loading the dataset returns four NumPy arrays:
# - The train_images and train_labels arrays are the training set—the data the model uses to learn.
# - The model is tested against the test set, the test_images, and test_labels arrays.

# %% [markdown]
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255. The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# | Label | Class |
# | --- | --- |
# | 0 | T-shirt/top
# | 1 | Trouser
# | 2 | Pullover
# | 3 | Dress
# | 4 | Coat
# | 5 | Sandal
# | 6 | Shirt
# | 7 | Sneaker
# | 8 | Bag
# | 9 | Ankle boot

# %% [markdown]
# Each Image is mapped to a single label. Since the class names are not included with the dataset, we should store them

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ## Preprocessing

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()

# %% [markdown]
# We can see from the above colorbar that the pixel values range from 0 to 255. Scale these values to a range of 0 to 1 before feeding them to the model. To do so, divide them by 255. It`s important that the training set and test set be pre-processed in the same way

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# To verify that the data is in the correct format and that you're ready to build and train the network, Let's display the first 20 images from training set along with their labels

# %%
plt.figure(figsize=(10,10))

for i in range(20): 
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i])
    plt.xlabel(class_names[train_labels[i]])

plt.show()

# %% [markdown]
# ## Building the Model

# %% [markdown]
# The basic building block of a neural network is the layer. Layers extract representations from the data fed fed into them. Hopefully, these representations are meaningful for the problem we`re solving.
#
# Most of deep learning consists of chaining together simple layers.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)), 
    tf.keras.layers.Dense(128, activation='relu'), 
    tf.keras.layers.Dense(10)
])

# %% [markdown]
# 1. The First layer in the network, `tf.keras.layers.Flatten`, transforms the format of the images from a two dimensional array(28 by 28 pixels) to a one-dimensional array(28 * 28 = 784 pixels). Think of this layer as unstacking rows of pixels in the image and lining them up. This layer has no parameters to learn, just formats the data.
# 2. Then, The Network consists of a sequence of two `Dense` layers. These are densely connected or fully connected layers. The first Dense layer has 128 nodes(or neurons). The second layer returns a logits array with length 10. Each node contains a score that indicates the current image belongs to one of the 10 classes.

# %% [markdown]
# ## Compile The Model

# %% [markdown]
# Before the model is trained, it needs a few more settings. These are added during the `compile` step.
# - Optimizer: This is how the model is updated based on the data it sees and its loss function.
# - Loss Function: This measure how accurate the model is during training. We want to minimize this fucntion to steer the model in the right direction.
# - Metrics: used to monitor the training and testing steps. We will use *accuracy*, the fractions of the images that are correctly classified.

# %%
model.compile(optimizer='adam', 
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy']
             )

# %% [markdown]
# ## Train the Model

# %% [markdown]
# Training the neural network model requires the following steps:
#
# 1. Feed the training data to the model. In this example, the training data is in the train_images and train_labels arrays.
# 2. The model learns to associate images and labels.
# 3. You ask the model to make predictions about a test set—in this example, the test_images array.
# 4. Verify that the predictions match the labels from the test_labels array.

# %% [markdown]
# ### Feed the Model

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 2024-12-25 11:53:30.688591: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7665 - loss: 0.6752
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8366 - loss: 0.4745
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8424 - loss: 0.4615
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8428 - loss: 0.4599
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8411 - loss: 0.4713
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.8358 - loss: 0.4827
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8406 - loss: 0.4731
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8417 - loss: 0.4805
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8427 - loss: 0.4829
# ...

# %% [markdown]
# As the model trains, the loss and accuracy metrics are displayed. This model reaches an accuracy of about 0.83 (or 83%) on the training data.

# %% [markdown]
# ### Evaluate Accuracy

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print("\nTest accuracy", test_acc)
# Out:
# 313/313 - 1s - 4ms/step - accuracy: 0.8123 - loss: 0.5747
#
# Test accuracy 0.8123000264167786

# %% [markdown]
# ### Make Predictions

# %% [markdown]
# With the model trained, you can use it to make predictions about some images. Attach a softmax layer to convert the model's linear outputs—logits—to probabilities, which should be easier to interpret.

# %%
probability_model = tf.keras.Sequential([model, tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Here the Model has predicted the label for each image in the testing set.

# %%
predictions[0]
# Out:
# array([1.4962271e-09, 8.8851235e-12, 2.3079338e-07, 2.9003836e-08,
#        2.9924973e-08, 1.9248456e-01, 1.6727364e-07, 3.9085796e-01,
#        2.1886504e-04, 4.1643813e-01], dtype=float32)

# %% [markdown]
# A Prediction is an array of 10 numbers. They represent the model`s confidence that the image corresponds to each of the 10 different labels. We can see which label has the highest confidence value

# %%
plt.figure()
plt.imshow(test_images[0])
plt.colorbar()
print(np.argmax(predictions[0]),class_names[np.argmax(predictions[0])])
# Out:
# 9 Ankle boot

# %%
plt.figure()
plt.imshow(test_images[20])
plt.colorbar()
print(np.argmax(predictions[20]),class_names[np.argmax(predictions[20])])
# Out:
# 2 Pullover

# %% [markdown]
# ### Verify predictions

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 2
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)

plt.subplot(1,2,2)
plot_value_array(i, predictions[i], test_labels)
plt.show()

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %% [markdown]
# Let's plot several images with their predictions. Note that the model can be wrong even when very confident.

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
